# %% [markdown]
# <a href="https://colab.research.google.com/github/SatrioHubs/PCVK_ganjil_2025/blob/main/Kelompok_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = cv.imread('/content/drive/MyDrive/20211222_102527.jpg')
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
rotated_img = cv.rotate(img2, cv.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(rotated_img)

# %%
img = cv.imread('/content/drive/MyDrive/20211222_102527.jpg')
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
rotated_img = cv.rotate(img2, cv.ROTATE_90_COUNTERCLOCKWISE)


start_point = (900, 1200)
end_point = (2400, 1500)


color = (255, 255, 255)
thickness = -1

image_with_rectangle = cv.rectangle(rotated_img.copy(), start_point, end_point, color, thickness)



plt.imshow(image_with_rectangle)

# %%
img = cv.imread('/content/drive/MyDrive/20211222_102527.jpg')
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
rotated_img = cv.rotate(img2, cv.ROTATE_90_COUNTERCLOCKWISE)


start_point = (900, 1200)
end_point = (2400, 1500)


color = (255, 255, 255)
thickness = -1

image_with_rectangle = cv.rectangle(rotated_img.copy(), start_point, end_point, color, thickness)

start_point = (800, 700)
end_point = (2300, 900)

color = (255, 0, 255)
thickness = -1

image_with_rectangle2 = cv.rectangle(image_with_rectangle.copy(), start_point, end_point, color, thickness)

plt.imshow(image_with_rectangle2)
